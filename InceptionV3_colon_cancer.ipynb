# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-marine/colon_cancer/blob/main/InceptionV3_colon_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Adding Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Moving to working directory**

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/thesis')
# !ls
# Out:
# '~'				  VGG16_colon_cancer.ipynb
#  InceptionV3_colon_cancer.ipynb   VGG19_colon_cancer.ipynb
#  ResNet50V2_colon_cancer.ipynb	  Xception_colon_cancer.ipynb

# %% [markdown]
# #**Importing required libraries**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# #**Data Preprocessing**

# %% [markdown]
# ##**Loading the data from form tensorflow_datasets**

# %%
tfds.disable_progress_bar()

# Reserve 10% for validation and 10% for test
(train_ds, validation_ds, test_ds), info = tfds.load("colorectal_histology",
                                                     split=["train[:80%]", "train[80%:90%]", "train[90%:]"],
                                                     as_supervised=True,
                                                     with_info=True)

print("Number of training examples: %d" % tf.data.experimental.cardinality(train_ds))
print("Number of validation examples: %d" % tf.data.experimental.cardinality(validation_ds))
print("Number of test examples: %d" % tf.data.experimental.cardinality(test_ds))

num_classes = info.features['label'].num_classes
print("Number of classes: %d" % num_classes)

original_image_size = info.features['image'].shape
print(f"Original image size: {original_image_size}")
# Out:
# Number of training examples: 4000
# Number of validation examples: 500
# Number of test examples: 500
# Number of classes: 8
# Original image size: (150, 150, 3)

# %%
# Get class names
class_names = info.features["label"].names
print(f"class names are: {class_names}")
# Out:
# class names are: ['tumor', 'stroma', 'complex', 'lympho', 'debris', 'mucosa', 'adipose', 'empty']

# %%
plt.figure(figsize=(12, 12))
for i, (image, label) in enumerate(train_ds.take(20)):
    ax = plt.subplot(4, 5, i + 1)
    plt.imshow(image)
    plt.title(class_names[int(label)])
    plt.axis("off")

# %% [markdown]
# ##**Standardizing the data**

# %%
# Resizing the images
img_size = (150, 150)

train_ds = train_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))
validation_ds = validation_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))
test_ds = test_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))

# %%
# Batch, cache, and prefetch the data
batch_size = 32
train_ds = train_ds.cache().batch(batch_size).prefetch(buffer_size=5)
validation_ds = validation_ds.cache().batch(batch_size).prefetch(buffer_size=5)
test_ds = test_ds.cache().batch(batch_size).prefetch(buffer_size=5)

# %% [markdown]
# ##**Random data augmentation**

# %%
# Creating a data augmentation stage with horizontal flipping, rotations and zooms
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
], name ="data_augmentation")

# %%
# Visualizing the 1st image of the 1st batch after 20 random augmentation
for images, labels in train_ds.take(1):
    plt.figure(figsize=(12, 12))
    image = images[0]
    for i in range(20):
        ax = plt.subplot(4, 5, i + 1)
        aug_img = data_augmentation(tf.expand_dims(image, 0), training=True)
        plt.imshow(tf.squeeze(aug_img).numpy().astype("int32"))
        plt.title(class_names[int(labels[0])])
        plt.axis("off")

# %% [markdown]
# #**Building models**

# %% [markdown]
# ##**InceptionV3**

# %%
from tensorflow.keras.applications import InceptionV3

# %% [markdown]
# **Feature Extraction**

# %%
# Setup input shape and base model
input_shape = img_size + (3, )
base_model = InceptionV3(weights="imagenet", input_shape=input_shape, include_top=False)

# Freeze the base_model
base_model.trainable = False

# Create a new model on top
inputs = keras.Input(shape=input_shape, name="input_layer")

# Apply random data augmentation
x = data_augmentation(inputs)  

# Scaling input to a range of (-1., +1.) from (0, 255) 
x = keras.layers.Rescaling(scale=1/127.5, offset=-1)(x)

# Running the base_model in inference mode so that batchnorm statistics don't get updated even for fine-tuning.
x = base_model(x, training=False)

# Convert outputs of the base model to vectors
x = keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

# Create the output activation layer
outputs = keras.layers.Dense(num_classes, activation="softmax", name="output_layer")(x)

# Combine the inputs with the outputs into a model
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# 87924736/87910968 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 150, 150, 3)]     0
#
#  data_augmentation (Sequenti  (None, 150, 150, 3)      0
#  al)
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  global_average_pooling_laye  (None, 2048)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 8)                 16392
#
# =================================================================
# Total params: 21,819,176
# Trainable params: 16,392
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
# Compiling InceptionV3 model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# Fit the model
history_feature_extraction = model.fit(train_ds, epochs=50, validation_data=validation_ds)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 203s 2s/step - loss: 1.0029 - accuracy: 0.6885 - val_loss: 0.6413 - val_accuracy: 0.8240
# Epoch 2/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.6107 - accuracy: 0.8152 - val_loss: 0.4619 - val_accuracy: 0.8580
# Epoch 3/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.5413 - accuracy: 0.8290 - val_loss: 0.4375 - val_accuracy: 0.8500
# Epoch 4/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.4994 - accuracy: 0.8428 - val_loss: 0.4206 - val_accuracy: 0.8540
# Epoch 5/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.4678 - accuracy: 0.8503 - val_loss: 0.3720 - val_accuracy: 0.8660
# Epoch 6/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.4221 - accuracy: 0.8610 - val_loss: 0.4202 - val_accuracy: 0.8620
# Epoch 7/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.4472 - accuracy: 0.8540 - val_loss: 0.3487 - val_accuracy: 0.8680
# Epoch 8/50
# 125/125 [==============================] - 199s 2s/step - loss: 0.4272 - accuracy: 0.8600 - val_loss: 0.3489 - val_accuracy: 0.8720
# Epoch 9/50
# 125/125 [==============================] - 201s 2s/step - loss: 0.4058 - accuracy: 0.8702 - val_loss: 0.3439 - val_accuracy: 0.8720
# Epoch 10/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3956 - accuracy: 0.8665 - val_loss: 0.3581 - val_accuracy: 0.8680
# Epoch 11/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3934 - accuracy: 0.8770 - val_loss: 0.3246 - val_accuracy: 0.8820
# Epoch 12/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3663 - accuracy: 0.8748 - val_loss: 0.2992 - val_accuracy: 0.8880
# Epoch 13/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3748 - accuracy: 0.8745 - val_loss: 0.3664 - val_accuracy: 0.8700
# Epoch 14/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3825 - accuracy: 0.8777 - val_loss: 0.3638 - val_accuracy: 0.8700
# Epoch 15/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3511 - accuracy: 0.8867 - val_loss: 0.3182 - val_accuracy: 0.8960
# Epoch 16/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3744 - accuracy: 0.8783 - val_loss: 0.3751 - val_accuracy: 0.8860
# Epoch 17/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3363 - accuracy: 0.8865 - val_loss: 0.3213 - val_accuracy: 0.8940
# Epoch 18/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3795 - accuracy: 0.8780 - val_loss: 0.3757 - val_accuracy: 0.8760
# Epoch 19/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.3855 - accuracy: 0.8760 - val_loss: 0.3218 - val_accuracy: 0.8900
# Epoch 20/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3739 - accuracy: 0.8733 - val_loss: 0.3699 - val_accuracy: 0.8740
# Epoch 21/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3458 - accuracy: 0.8820 - val_loss: 0.3725 - val_accuracy: 0.8740
# Epoch 22/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3458 - accuracy: 0.8857 - val_loss: 0.3803 - val_accuracy: 0.8620
# Epoch 23/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3754 - accuracy: 0.8792 - val_loss: 0.3922 - val_accuracy: 0.8640
# Epoch 24/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3354 - accuracy: 0.8855 - val_loss: 0.3284 - val_accuracy: 0.8920
# Epoch 25/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3195 - accuracy: 0.8935 - val_loss: 0.3404 - val_accuracy: 0.8880
# Epoch 26/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3183 - accuracy: 0.8905 - val_loss: 0.3708 - val_accuracy: 0.8640
# Epoch 27/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3465 - accuracy: 0.8825 - val_loss: 0.3306 - val_accuracy: 0.8780
# Epoch 28/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3319 - accuracy: 0.8903 - val_loss: 0.3256 - val_accuracy: 0.9040
# Epoch 29/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3375 - accuracy: 0.8882 - val_loss: 0.3356 - val_accuracy: 0.8900
# Epoch 30/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3180 - accuracy: 0.8923 - val_loss: 0.3868 - val_accuracy: 0.8800
# Epoch 31/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3198 - accuracy: 0.9032 - val_loss: 0.3712 - val_accuracy: 0.8900
# Epoch 32/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3343 - accuracy: 0.8907 - val_loss: 0.3079 - val_accuracy: 0.8980
# Epoch 33/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3057 - accuracy: 0.8980 - val_loss: 0.2788 - val_accuracy: 0.9020
# Epoch 34/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.3152 - accuracy: 0.8955 - val_loss: 0.3077 - val_accuracy: 0.8920
# Epoch 35/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.3451 - accuracy: 0.8873 - val_loss: 0.3934 - val_accuracy: 0.8740
# Epoch 36/50
# 125/125 [==============================] - 188s 2s/step - loss: 0.3398 - accuracy: 0.8925 - val_loss: 0.3671 - val_accuracy: 0.8840
# Epoch 37/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.3155 - accuracy: 0.8965 - val_loss: 0.3491 - val_accuracy: 0.8880
# Epoch 38/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2984 - accuracy: 0.9003 - val_loss: 0.3620 - val_accuracy: 0.8880
# Epoch 39/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.3157 - accuracy: 0.8950 - val_loss: 0.3394 - val_accuracy: 0.8960
# Epoch 40/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.3062 - accuracy: 0.8925 - val_loss: 0.3325 - val_accuracy: 0.8900
# Epoch 41/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2983 - accuracy: 0.9047 - val_loss: 0.3487 - val_accuracy: 0.8740
# Epoch 42/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.3198 - accuracy: 0.8885 - val_loss: 0.4024 - val_accuracy: 0.8780
# Epoch 43/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.3063 - accuracy: 0.8980 - val_loss: 0.4059 - val_accuracy: 0.8760
# Epoch 44/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2973 - accuracy: 0.8982 - val_loss: 0.3244 - val_accuracy: 0.9000
# Epoch 45/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.2984 - accuracy: 0.9015 - val_loss: 0.3718 - val_accuracy: 0.8840
# Epoch 46/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2752 - accuracy: 0.9040 - val_loss: 0.3168 - val_accuracy: 0.8820
# Epoch 47/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.2960 - accuracy: 0.8965 - val_loss: 0.3578 - val_accuracy: 0.8780
# Epoch 48/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2930 - accuracy: 0.9013 - val_loss: 0.4626 - val_accuracy: 0.8620
# Epoch 49/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.3029 - accuracy: 0.8953 - val_loss: 0.3422 - val_accuracy: 0.8900
# Epoch 50/50
# 125/125 [==============================] - 189s 2s/step - loss: 0.2923 - accuracy: 0.9038 - val_loss: 0.3281 - val_accuracy: 0.8940

# %% [markdown]
# **Fine tuning the InceptionV3**

# %%
# Unfreeze the entire base model
base_model.trainable = True

# Freeze all layers except the last 10 layers
for layer in base_model.layers[:-10]:
  layer.trainable = False

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 150, 150, 3)]     0
#
#  data_augmentation (Sequenti  (None, 150, 150, 3)      0
#  al)
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  global_average_pooling_laye  (None, 2048)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 8)                 16392
#
# =================================================================
# Total params: 21,819,176
# Trainable params: 16,584
# Non-trainable params: 21,802,592
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
              metrics=["accuracy"])

# Fit the model
history_fine_tuning = model.fit(train_ds, epochs=50, validation_data=validation_ds)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 198s 2s/step - loss: 0.2830 - accuracy: 0.9018 - val_loss: 0.2958 - val_accuracy: 0.8920
# Epoch 2/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2594 - accuracy: 0.9145 - val_loss: 0.2904 - val_accuracy: 0.8980
# Epoch 3/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2571 - accuracy: 0.9100 - val_loss: 0.2892 - val_accuracy: 0.8960
# Epoch 4/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2442 - accuracy: 0.9160 - val_loss: 0.2896 - val_accuracy: 0.9000
# Epoch 5/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2577 - accuracy: 0.9120 - val_loss: 0.2925 - val_accuracy: 0.8980
# Epoch 6/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2333 - accuracy: 0.9180 - val_loss: 0.2941 - val_accuracy: 0.8960
# Epoch 7/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2577 - accuracy: 0.9122 - val_loss: 0.2927 - val_accuracy: 0.8980
# Epoch 8/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2423 - accuracy: 0.9147 - val_loss: 0.2925 - val_accuracy: 0.8980
# Epoch 9/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2348 - accuracy: 0.9153 - val_loss: 0.2885 - val_accuracy: 0.9000
# Epoch 10/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2412 - accuracy: 0.9195 - val_loss: 0.2880 - val_accuracy: 0.9020
# Epoch 11/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2560 - accuracy: 0.9085 - val_loss: 0.2894 - val_accuracy: 0.8980
# Epoch 12/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2511 - accuracy: 0.9137 - val_loss: 0.2889 - val_accuracy: 0.9020
# Epoch 13/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2444 - accuracy: 0.9112 - val_loss: 0.2852 - val_accuracy: 0.9020
# Epoch 14/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2427 - accuracy: 0.9193 - val_loss: 0.2868 - val_accuracy: 0.9040
# Epoch 15/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2510 - accuracy: 0.9130 - val_loss: 0.2852 - val_accuracy: 0.9020
# Epoch 16/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2401 - accuracy: 0.9160 - val_loss: 0.2837 - val_accuracy: 0.9040
# Epoch 17/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2449 - accuracy: 0.9200 - val_loss: 0.2852 - val_accuracy: 0.9020
# Epoch 18/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2478 - accuracy: 0.9168 - val_loss: 0.2853 - val_accuracy: 0.9040
# Epoch 19/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2456 - accuracy: 0.9143 - val_loss: 0.2854 - val_accuracy: 0.9060
# Epoch 20/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2309 - accuracy: 0.9227 - val_loss: 0.2851 - val_accuracy: 0.9040
# Epoch 21/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2528 - accuracy: 0.9160 - val_loss: 0.2884 - val_accuracy: 0.9020
# Epoch 22/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2350 - accuracy: 0.9185 - val_loss: 0.2834 - val_accuracy: 0.9040
# Epoch 23/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2386 - accuracy: 0.9187 - val_loss: 0.2873 - val_accuracy: 0.9100
# Epoch 24/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2403 - accuracy: 0.9137 - val_loss: 0.2823 - val_accuracy: 0.9140
# Epoch 25/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2408 - accuracy: 0.9150 - val_loss: 0.2823 - val_accuracy: 0.9020
# Epoch 26/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2489 - accuracy: 0.9150 - val_loss: 0.2812 - val_accuracy: 0.9100
# Epoch 27/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2575 - accuracy: 0.9115 - val_loss: 0.2835 - val_accuracy: 0.9060
# Epoch 28/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2440 - accuracy: 0.9197 - val_loss: 0.2840 - val_accuracy: 0.9120
# Epoch 29/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2436 - accuracy: 0.9153 - val_loss: 0.2864 - val_accuracy: 0.9060
# Epoch 30/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2335 - accuracy: 0.9178 - val_loss: 0.2858 - val_accuracy: 0.9060
# Epoch 31/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2266 - accuracy: 0.9190 - val_loss: 0.2827 - val_accuracy: 0.9060
# Epoch 32/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2409 - accuracy: 0.9147 - val_loss: 0.2831 - val_accuracy: 0.9040
# Epoch 33/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2493 - accuracy: 0.9153 - val_loss: 0.2857 - val_accuracy: 0.9040
# Epoch 34/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2325 - accuracy: 0.9160 - val_loss: 0.2838 - val_accuracy: 0.9060
# Epoch 35/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2243 - accuracy: 0.9240 - val_loss: 0.2813 - val_accuracy: 0.9100
# Epoch 36/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2507 - accuracy: 0.9125 - val_loss: 0.2806 - val_accuracy: 0.9080
# Epoch 37/50
# 125/125 [==============================] - 193s 2s/step - loss: 0.2400 - accuracy: 0.9183 - val_loss: 0.2805 - val_accuracy: 0.9080
# Epoch 38/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2420 - accuracy: 0.9165 - val_loss: 0.2795 - val_accuracy: 0.9120
# Epoch 39/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2346 - accuracy: 0.9147 - val_loss: 0.2785 - val_accuracy: 0.9100
# Epoch 40/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2391 - accuracy: 0.9210 - val_loss: 0.2783 - val_accuracy: 0.9140
# Epoch 41/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2332 - accuracy: 0.9208 - val_loss: 0.2822 - val_accuracy: 0.9100
# Epoch 42/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2331 - accuracy: 0.9168 - val_loss: 0.2821 - val_accuracy: 0.9080
# Epoch 43/50
# 125/125 [==============================] - 190s 2s/step - loss: 0.2302 - accuracy: 0.9200 - val_loss: 0.2801 - val_accuracy: 0.9160
# Epoch 44/50
# 125/125 [==============================] - 192s 2s/step - loss: 0.2390 - accuracy: 0.9170 - val_loss: 0.2815 - val_accuracy: 0.9120
# Epoch 45/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2351 - accuracy: 0.9175 - val_loss: 0.2809 - val_accuracy: 0.9100
# Epoch 46/50
# 125/125 [==============================] - 193s 2s/step - loss: 0.2518 - accuracy: 0.9137 - val_loss: 0.2806 - val_accuracy: 0.9120
# Epoch 47/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2348 - accuracy: 0.9150 - val_loss: 0.2808 - val_accuracy: 0.9100
# Epoch 48/50
# 125/125 [==============================] - 193s 2s/step - loss: 0.2365 - accuracy: 0.9247 - val_loss: 0.2835 - val_accuracy: 0.9080
# Epoch 49/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2279 - accuracy: 0.9235 - val_loss: 0.2780 - val_accuracy: 0.9120
# Epoch 50/50
# 125/125 [==============================] - 191s 2s/step - loss: 0.2231 - accuracy: 0.9200 - val_loss: 0.2788 - val_accuracy: 0.9100

# %% [markdown]
# ###**Evaluation**

# %% [markdown]
# **Loss Curve**

# %%
# Comparing accuracy and loss curves for training and validation sets for feature extraction and fine-tuning 
loss_fn = history_fine_tuning.history['loss']
val_loss_fn = history_fine_tuning.history['val_loss']
accuracy_fn = history_fine_tuning.history['accuracy']
val_accuracy_fn = history_fine_tuning.history['val_accuracy']

loss_fe = history_feature_extraction.history['loss']
val_loss_fe = history_feature_extraction.history['val_loss']
accuracy_fe = history_feature_extraction.history['accuracy']
val_accuracy_fe = history_feature_extraction.history['val_accuracy']

epochs = range(len(history_fine_tuning.history['loss']))

# Plotting loss curve
plt.figure()
plt.plot(epochs, loss_fn, label='training loss - fine-tuning')
plt.plot(epochs, val_loss_fn, label='val loss - fine-tuning')
plt.plot(epochs, loss_fe, label='training loss - feature extraction')
plt.plot(epochs, val_loss_fe, label='val loss - feature extraction')
plt.title('Loss Curve of InceptionV3')
plt.xlabel('Epochs')
plt.legend();

# Plotting accuracy
plt.figure()
plt.plot(epochs, accuracy_fn, label='training_accuracy - fine-tuning')
plt.plot(epochs, val_accuracy_fn, label='val_accuracy - fine-tuning')
plt.plot(epochs, accuracy_fe, label='training_accuracy - feature extraction')
plt.plot(epochs, val_accuracy_fe, label='val_accuracy - feature extraction')
plt.title('Accuracy of InceptionV3')
plt.xlabel('Epochs')
plt.legend();

# %% [markdown]
# **Evaluating using the testing data**

# %%
loss, accuracy = model.evaluate(test_ds, batch_size=32)
print(f"Model loss on test set: {(loss):.2f}")
print(f"Model accuracy on test set: {(accuracy*100):.2f}%")
# Out:
# 16/16 [==============================] - 23s 1s/step - loss: 0.3344 - accuracy: 0.9000
# Model loss on test set: 0.33
# Model accuracy on test set: 90.00%

# %% [markdown]
# **Confusion Matrix**

# %%
# Model prediction for test data
pred = model.predict(test_ds)

# Match the prediction class to the highest prediction probability
y_pred = [pred[i].argmax() for i in range(len(pred))]
y_pred_class = [class_names[y_pred[i]] for i in range(len(y_pred))]

# Extract the truth ground label and match to class_names 
y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_true_class = [class_names[y_true[i]] for i in range(len(y_true))]

# %%
# Plotting confusion matrix
cm = confusion_matrix(y_true=y_true, y_pred=y_pred)
plt.figure(figsize=(10,8))
ax = sns.heatmap(cm/np.sum(cm),fmt='.2%', annot=True, cmap='YlOrRd')
ax.set_title('Confusion Matrix\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.show()

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_true_class, y_pred_class, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      adipose      1.000     1.000     1.000        57
#      complex      0.812     0.765     0.788        68
#       debris      0.845     0.882     0.863        68
#        empty      0.983     1.000     0.992        59
#       lympho      0.868     0.937     0.901        63
#       mucosa      0.951     0.967     0.959        60
#       stroma      0.821     0.793     0.807        58
#        tumor      0.937     0.881     0.908        67
#
#     accuracy                          0.900       500
#    macro avg      0.902     0.903     0.902       500
# weighted avg      0.900     0.900     0.899       500
