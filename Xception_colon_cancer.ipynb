# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-marine/colon_cancer/blob/main/Xception_colon_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Adding Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Moving to working directory**

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/thesis')
# !ls
# Out:
# '~'				  VGG16_colon_cancer.ipynb
#  InceptionV3_colon_cancer.ipynb   VGG19_colon_cancer.ipynb
#  ResNet50V2_colon_cancer.ipynb	  Xception_colon_cancer.ipynb

# %% [markdown]
# #**Importing required libraries**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# #**Data Preprocessing**

# %% [markdown]
# ##**Loading the data from form tensorflow_datasets**

# %%
tfds.disable_progress_bar()

# Reserve 10% for validation and 10% for test
(train_ds, validation_ds, test_ds), info = tfds.load("colorectal_histology",
                                                     split=["train[:80%]", "train[80%:90%]", "train[90%:]"],
                                                     as_supervised=True,
                                                     with_info=True)

print("Number of training examples: %d" % tf.data.experimental.cardinality(train_ds))
print("Number of validation examples: %d" % tf.data.experimental.cardinality(validation_ds))
print("Number of test examples: %d" % tf.data.experimental.cardinality(test_ds))

num_classes = info.features['label'].num_classes
print("Number of classes: %d" % num_classes)

original_image_size = info.features['image'].shape
print(f"Original image size: {original_image_size}")
# Out:
# Number of training examples: 4000
# Number of validation examples: 500
# Number of test examples: 500
# Number of classes: 8
# Original image size: (150, 150, 3)

# %%
# Get class names
class_names = info.features["label"].names
print(f"class names are: {class_names}")
# Out:
# class names are: ['tumor', 'stroma', 'complex', 'lympho', 'debris', 'mucosa', 'adipose', 'empty']

# %%
plt.figure(figsize=(12, 12))
for i, (image, label) in enumerate(train_ds.take(20)):
    ax = plt.subplot(4, 5, i + 1)
    plt.imshow(image)
    plt.title(class_names[int(label)])
    plt.axis("off")

# %% [markdown]
# ##**Standardizing the data**

# %%
# Resizing the images
img_size = (150, 150)

train_ds = train_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))
validation_ds = validation_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))
test_ds = test_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))

# %%
# Batch, cache, and prefetch the data
batch_size = 32
train_ds = train_ds.cache().batch(batch_size).prefetch(buffer_size=5)
validation_ds = validation_ds.cache().batch(batch_size).prefetch(buffer_size=5)
test_ds = test_ds.cache().batch(batch_size).prefetch(buffer_size=5)

# %% [markdown]
# ##**Random data augmentation**

# %%
# Creating a data augmentation stage with horizontal flipping, rotations and zooms
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
], name ="data_augmentation")

# %%
# Visualizing the 1st image of the 1st batch after 20 random augmentation
for images, labels in train_ds.take(1):
    plt.figure(figsize=(12, 12))
    image = images[0]
    for i in range(20):
        ax = plt.subplot(4, 5, i + 1)
        aug_img = data_augmentation(tf.expand_dims(image, 0), training=True)
        plt.imshow(tf.squeeze(aug_img).numpy().astype("int32"))
        plt.title(class_names[int(labels[0])])
        plt.axis("off")

# %% [markdown]
# #**Building models**

# %% [markdown]
# ##**Xception**

# %%
from tensorflow.keras.applications import Xception

# %% [markdown]
# **Feature Extraction**

# %%
# Setup input shape and base model
input_shape = img_size + (3, )
base_model = Xception(weights="imagenet", input_shape=input_shape, include_top=False)

# Freeze the base_model
base_model.trainable = False

# Create a new model on top
inputs = keras.Input(shape=input_shape, name="input_layer")

# Apply random data augmentation
x = data_augmentation(inputs)  

# Scaling input to a range of (-1., +1.) from (0, 255) 
x = keras.layers.Rescaling(scale=1/127.5, offset=-1)(x)

# Running the base_model in inference mode so that batchnorm statistics don't get updated even for fine-tuning.
x = base_model(x, training=False)

# Convert outputs of the base model to vectors
x = keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

# Create the output activation layer
outputs = keras.layers.Dense(num_classes, activation="softmax", name="output_layer")(x)

# Combine the inputs with the outputs into a model
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 0s 0us/step
# 83697664/83683744 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 150, 150, 3)]     0
#
#  data_augmentation (Sequenti  (None, 150, 150, 3)      0
#  al)
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  xception (Functional)       (None, 5, 5, 2048)        20861480
#
#  global_average_pooling_laye  (None, 2048)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 8)                 16392
#
# =================================================================
# Total params: 20,877,872
# Trainable params: 16,392
# Non-trainable params: 20,861,480
# _________________________________________________________________

# %%
# Compiling Xception model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# Fit the model
history_feature_extraction = model.fit(train_ds, epochs=50, validation_data=validation_ds)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 313s 2s/step - loss: 0.9495 - accuracy: 0.7345 - val_loss: 0.6445 - val_accuracy: 0.8440
# Epoch 2/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.6383 - accuracy: 0.8487 - val_loss: 0.5332 - val_accuracy: 0.8840
# Epoch 3/50
# 125/125 [==============================] - 310s 2s/step - loss: 0.5545 - accuracy: 0.8637 - val_loss: 0.4960 - val_accuracy: 0.8720
# Epoch 4/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.4885 - accuracy: 0.8775 - val_loss: 0.4600 - val_accuracy: 0.8720
# Epoch 5/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.4591 - accuracy: 0.8808 - val_loss: 0.4050 - val_accuracy: 0.8820
# Epoch 6/50
# 125/125 [==============================] - 301s 2s/step - loss: 0.4195 - accuracy: 0.8890 - val_loss: 0.3983 - val_accuracy: 0.8920
# Epoch 7/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.4153 - accuracy: 0.8825 - val_loss: 0.3770 - val_accuracy: 0.8840
# Epoch 8/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.3731 - accuracy: 0.8953 - val_loss: 0.3688 - val_accuracy: 0.8820
# Epoch 9/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.3616 - accuracy: 0.8940 - val_loss: 0.3451 - val_accuracy: 0.9020
# Epoch 10/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.3420 - accuracy: 0.9007 - val_loss: 0.3289 - val_accuracy: 0.9060
# Epoch 11/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.3366 - accuracy: 0.8988 - val_loss: 0.3231 - val_accuracy: 0.9000
# Epoch 12/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.3315 - accuracy: 0.8980 - val_loss: 0.3023 - val_accuracy: 0.9080
# Epoch 13/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.3086 - accuracy: 0.9053 - val_loss: 0.3132 - val_accuracy: 0.9020
# Epoch 14/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.3062 - accuracy: 0.9080 - val_loss: 0.2854 - val_accuracy: 0.9100
# Epoch 15/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.3036 - accuracy: 0.9020 - val_loss: 0.2945 - val_accuracy: 0.9020
# Epoch 16/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2828 - accuracy: 0.9100 - val_loss: 0.2992 - val_accuracy: 0.9040
# Epoch 17/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2922 - accuracy: 0.9032 - val_loss: 0.2989 - val_accuracy: 0.9040
# Epoch 18/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2728 - accuracy: 0.9087 - val_loss: 0.3125 - val_accuracy: 0.9140
# Epoch 19/50
# 125/125 [==============================] - 311s 2s/step - loss: 0.2701 - accuracy: 0.9093 - val_loss: 0.2961 - val_accuracy: 0.9120
# Epoch 20/50
# 125/125 [==============================] - 305s 2s/step - loss: 0.2684 - accuracy: 0.9133 - val_loss: 0.2746 - val_accuracy: 0.9160
# Epoch 21/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2631 - accuracy: 0.9143 - val_loss: 0.2807 - val_accuracy: 0.9160
# Epoch 22/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2649 - accuracy: 0.9143 - val_loss: 0.2681 - val_accuracy: 0.9140
# Epoch 23/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2469 - accuracy: 0.9187 - val_loss: 0.2661 - val_accuracy: 0.9100
# Epoch 24/50
# 125/125 [==============================] - 301s 2s/step - loss: 0.2529 - accuracy: 0.9125 - val_loss: 0.2717 - val_accuracy: 0.9100
# Epoch 25/50
# 125/125 [==============================] - 304s 2s/step - loss: 0.2479 - accuracy: 0.9153 - val_loss: 0.2638 - val_accuracy: 0.9140
# Epoch 26/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2413 - accuracy: 0.9183 - val_loss: 0.2708 - val_accuracy: 0.9080
# Epoch 27/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2298 - accuracy: 0.9245 - val_loss: 0.2626 - val_accuracy: 0.9060
# Epoch 28/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2588 - accuracy: 0.9110 - val_loss: 0.2588 - val_accuracy: 0.9120
# Epoch 29/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2419 - accuracy: 0.9180 - val_loss: 0.2520 - val_accuracy: 0.9020
# Epoch 30/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2277 - accuracy: 0.9218 - val_loss: 0.2496 - val_accuracy: 0.9140
# Epoch 31/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2165 - accuracy: 0.9280 - val_loss: 0.2567 - val_accuracy: 0.9120
# Epoch 32/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2347 - accuracy: 0.9193 - val_loss: 0.2650 - val_accuracy: 0.9020
# Epoch 33/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2308 - accuracy: 0.9205 - val_loss: 0.2427 - val_accuracy: 0.9120
# Epoch 34/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2173 - accuracy: 0.9285 - val_loss: 0.2535 - val_accuracy: 0.9120
# Epoch 35/50
# 125/125 [==============================] - 304s 2s/step - loss: 0.2359 - accuracy: 0.9195 - val_loss: 0.2493 - val_accuracy: 0.9040
# Epoch 36/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2204 - accuracy: 0.9247 - val_loss: 0.2607 - val_accuracy: 0.9040
# Epoch 37/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2234 - accuracy: 0.9210 - val_loss: 0.2574 - val_accuracy: 0.9140
# Epoch 38/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2071 - accuracy: 0.9315 - val_loss: 0.2549 - val_accuracy: 0.9080
# Epoch 39/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2201 - accuracy: 0.9243 - val_loss: 0.2510 - val_accuracy: 0.9100
# Epoch 40/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2061 - accuracy: 0.9277 - val_loss: 0.2426 - val_accuracy: 0.9160
# Epoch 41/50
# 125/125 [==============================] - 301s 2s/step - loss: 0.2157 - accuracy: 0.9243 - val_loss: 0.2543 - val_accuracy: 0.9100
# Epoch 42/50
# 125/125 [==============================] - 301s 2s/step - loss: 0.2227 - accuracy: 0.9258 - val_loss: 0.2394 - val_accuracy: 0.9100
# Epoch 43/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2139 - accuracy: 0.9250 - val_loss: 0.2359 - val_accuracy: 0.9160
# Epoch 44/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2199 - accuracy: 0.9237 - val_loss: 0.2488 - val_accuracy: 0.9140
# Epoch 45/50
# 125/125 [==============================] - 301s 2s/step - loss: 0.2066 - accuracy: 0.9270 - val_loss: 0.2495 - val_accuracy: 0.9060
# Epoch 46/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2027 - accuracy: 0.9327 - val_loss: 0.2364 - val_accuracy: 0.9180
# Epoch 47/50
# 125/125 [==============================] - 301s 2s/step - loss: 0.2085 - accuracy: 0.9275 - val_loss: 0.2741 - val_accuracy: 0.9100
# Epoch 48/50
# 125/125 [==============================] - 302s 2s/step - loss: 0.2139 - accuracy: 0.9275 - val_loss: 0.2705 - val_accuracy: 0.9160
# Epoch 49/50
# 125/125 [==============================] - 301s 2s/step - loss: 0.2002 - accuracy: 0.9290 - val_loss: 0.2625 - val_accuracy: 0.9160
# Epoch 50/50
# 125/125 [==============================] - 303s 2s/step - loss: 0.2019 - accuracy: 0.9268 - val_loss: 0.2488 - val_accuracy: 0.9100

# %% [markdown]
# **Fine tuning the Xception**

# %%
# Unfreeze the entire base model
base_model.trainable = True

# Freeze all layers except the last 10 layers
for layer in base_model.layers[:-10]:
  layer.trainable = False

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 150, 150, 3)]     0
#
#  data_augmentation (Sequenti  (None, 150, 150, 3)      0
#  al)
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  xception (Functional)       (None, 5, 5, 2048)        20861480
#
#  global_average_pooling_laye  (None, 2048)             0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 8)                 16392
#
# =================================================================
# Total params: 20,877,872
# Trainable params: 5,512,712
# Non-trainable params: 15,365,160
# _________________________________________________________________

# %%
# Compile the model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),
              metrics=["accuracy"])

# Fit the model
history_fine_tuning = model.fit(train_ds, epochs=50, validation_data=validation_ds)
# Out:
# Epoch 1/50
# 125/125 [==============================] - 376s 3s/step - loss: 0.1928 - accuracy: 0.9320 - val_loss: 0.2263 - val_accuracy: 0.9200
# Epoch 2/50
# 125/125 [==============================] - 372s 3s/step - loss: 0.1752 - accuracy: 0.9373 - val_loss: 0.2208 - val_accuracy: 0.9240
# Epoch 3/50
# 125/125 [==============================] - 372s 3s/step - loss: 0.1813 - accuracy: 0.9320 - val_loss: 0.2167 - val_accuracy: 0.9160
# Epoch 4/50
# 125/125 [==============================] - 372s 3s/step - loss: 0.1671 - accuracy: 0.9392 - val_loss: 0.2122 - val_accuracy: 0.9240
# Epoch 5/50
# 125/125 [==============================] - 372s 3s/step - loss: 0.1625 - accuracy: 0.9430 - val_loss: 0.2132 - val_accuracy: 0.9260
# Epoch 6/50
# 125/125 [==============================] - 371s 3s/step - loss: 0.1620 - accuracy: 0.9435 - val_loss: 0.2150 - val_accuracy: 0.9320
# Epoch 7/50
# 125/125 [==============================] - 371s 3s/step - loss: 0.1586 - accuracy: 0.9430 - val_loss: 0.2150 - val_accuracy: 0.9280
# Epoch 8/50
# 125/125 [==============================] - 371s 3s/step - loss: 0.1542 - accuracy: 0.9457 - val_loss: 0.2219 - val_accuracy: 0.9240
# Epoch 9/50
# 125/125 [==============================] - 370s 3s/step - loss: 0.1516 - accuracy: 0.9445 - val_loss: 0.2120 - val_accuracy: 0.9200
# Epoch 10/50
# 125/125 [==============================] - 369s 3s/step - loss: 0.1535 - accuracy: 0.9495 - val_loss: 0.2136 - val_accuracy: 0.9260
# Epoch 11/50
# 125/125 [==============================] - 370s 3s/step - loss: 0.1457 - accuracy: 0.9492 - val_loss: 0.2109 - val_accuracy: 0.9280
# Epoch 12/50
# 125/125 [==============================] - 370s 3s/step - loss: 0.1485 - accuracy: 0.9405 - val_loss: 0.2075 - val_accuracy: 0.9320
# Epoch 13/50
# 125/125 [==============================] - 370s 3s/step - loss: 0.1434 - accuracy: 0.9480 - val_loss: 0.2091 - val_accuracy: 0.9320
# Epoch 14/50
# 125/125 [==============================] - 370s 3s/step - loss: 0.1286 - accuracy: 0.9548 - val_loss: 0.2067 - val_accuracy: 0.9260
# Epoch 15/50
# 125/125 [==============================] - 370s 3s/step - loss: 0.1381 - accuracy: 0.9532 - val_loss: 0.2009 - val_accuracy: 0.9260
# Epoch 16/50
# 125/125 [==============================] - 372s 3s/step - loss: 0.1406 - accuracy: 0.9480 - val_loss: 0.1960 - val_accuracy: 0.9280
# Epoch 17/50
# 125/125 [==============================] - 373s 3s/step - loss: 0.1233 - accuracy: 0.9535 - val_loss: 0.2012 - val_accuracy: 0.9220
# Epoch 18/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.1367 - accuracy: 0.9507 - val_loss: 0.2056 - val_accuracy: 0.9340
# Epoch 19/50
# 125/125 [==============================] - 373s 3s/step - loss: 0.1358 - accuracy: 0.9500 - val_loss: 0.2100 - val_accuracy: 0.9300
# Epoch 20/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.1247 - accuracy: 0.9575 - val_loss: 0.2045 - val_accuracy: 0.9340
# Epoch 21/50
# 125/125 [==============================] - 373s 3s/step - loss: 0.1307 - accuracy: 0.9528 - val_loss: 0.2117 - val_accuracy: 0.9220
# Epoch 22/50
# 125/125 [==============================] - 378s 3s/step - loss: 0.1306 - accuracy: 0.9528 - val_loss: 0.2070 - val_accuracy: 0.9200
# Epoch 23/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.1236 - accuracy: 0.9530 - val_loss: 0.1917 - val_accuracy: 0.9280
# Epoch 24/50
# 125/125 [==============================] - 373s 3s/step - loss: 0.1186 - accuracy: 0.9582 - val_loss: 0.1966 - val_accuracy: 0.9320
# Epoch 25/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.1277 - accuracy: 0.9532 - val_loss: 0.1905 - val_accuracy: 0.9260
# Epoch 26/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.1152 - accuracy: 0.9607 - val_loss: 0.1955 - val_accuracy: 0.9280
# Epoch 27/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.1162 - accuracy: 0.9585 - val_loss: 0.1851 - val_accuracy: 0.9300
# Epoch 28/50
# 125/125 [==============================] - 372s 3s/step - loss: 0.1091 - accuracy: 0.9625 - val_loss: 0.1996 - val_accuracy: 0.9340
# Epoch 29/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.1086 - accuracy: 0.9622 - val_loss: 0.2054 - val_accuracy: 0.9300
# Epoch 30/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.1034 - accuracy: 0.9653 - val_loss: 0.1989 - val_accuracy: 0.9260
# Epoch 31/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.1129 - accuracy: 0.9607 - val_loss: 0.1909 - val_accuracy: 0.9300
# Epoch 32/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.1088 - accuracy: 0.9620 - val_loss: 0.1994 - val_accuracy: 0.9340
# Epoch 33/50
# 125/125 [==============================] - 373s 3s/step - loss: 0.1020 - accuracy: 0.9645 - val_loss: 0.1923 - val_accuracy: 0.9300
# Epoch 34/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.0993 - accuracy: 0.9640 - val_loss: 0.1887 - val_accuracy: 0.9400
# Epoch 35/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.1015 - accuracy: 0.9640 - val_loss: 0.1892 - val_accuracy: 0.9340
# Epoch 36/50
# 125/125 [==============================] - 376s 3s/step - loss: 0.1036 - accuracy: 0.9603 - val_loss: 0.1853 - val_accuracy: 0.9360
# Epoch 37/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0949 - accuracy: 0.9672 - val_loss: 0.1858 - val_accuracy: 0.9340
# Epoch 38/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0950 - accuracy: 0.9672 - val_loss: 0.1923 - val_accuracy: 0.9340
# Epoch 39/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.1103 - accuracy: 0.9595 - val_loss: 0.1862 - val_accuracy: 0.9360
# Epoch 40/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.1028 - accuracy: 0.9682 - val_loss: 0.1960 - val_accuracy: 0.9300
# Epoch 41/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0944 - accuracy: 0.9690 - val_loss: 0.1927 - val_accuracy: 0.9300
# Epoch 42/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0928 - accuracy: 0.9670 - val_loss: 0.1957 - val_accuracy: 0.9400
# Epoch 43/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0981 - accuracy: 0.9688 - val_loss: 0.1860 - val_accuracy: 0.9280
# Epoch 44/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.1076 - accuracy: 0.9580 - val_loss: 0.1902 - val_accuracy: 0.9320
# Epoch 45/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0951 - accuracy: 0.9675 - val_loss: 0.1823 - val_accuracy: 0.9400
# Epoch 46/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0963 - accuracy: 0.9650 - val_loss: 0.1787 - val_accuracy: 0.9420
# Epoch 47/50
# 125/125 [==============================] - 376s 3s/step - loss: 0.0935 - accuracy: 0.9660 - val_loss: 0.1822 - val_accuracy: 0.9340
# Epoch 48/50
# 125/125 [==============================] - 375s 3s/step - loss: 0.0967 - accuracy: 0.9657 - val_loss: 0.1859 - val_accuracy: 0.9300
# Epoch 49/50
# 125/125 [==============================] - 374s 3s/step - loss: 0.0846 - accuracy: 0.9695 - val_loss: 0.1806 - val_accuracy: 0.9420
# Epoch 50/50
# 125/125 [==============================] - 377s 3s/step - loss: 0.0870 - accuracy: 0.9700 - val_loss: 0.2006 - val_accuracy: 0.9300

# %% [markdown]
# ###**Evaluation**

# %% [markdown]
# **Loss Curve**

# %%
# Comparing accuracy and loss curves for training and validation sets for feature extraction and fine-tuning 
loss_fn = history_fine_tuning.history['loss']
val_loss_fn = history_fine_tuning.history['val_loss']
accuracy_fn = history_fine_tuning.history['accuracy']
val_accuracy_fn = history_fine_tuning.history['val_accuracy']

loss_fe = history_feature_extraction.history['loss']
val_loss_fe = history_feature_extraction.history['val_loss']
accuracy_fe = history_feature_extraction.history['accuracy']
val_accuracy_fe = history_feature_extraction.history['val_accuracy']

epochs = range(len(history_fine_tuning.history['loss']))

# Plotting loss curve
plt.figure()
plt.plot(epochs, loss_fn, label='training loss - fine-tuning')
plt.plot(epochs, val_loss_fn, label='val loss - fine-tuning')
plt.plot(epochs, loss_fe, label='training loss - feature extraction')
plt.plot(epochs, val_loss_fe, label='val loss - feature extraction')
plt.title('Loss Curve of Xception')
plt.xlabel('Epochs')
plt.legend();

# Plotting accuracy
plt.figure()
plt.plot(epochs, accuracy_fn, label='training_accuracy - fine-tuning')
plt.plot(epochs, val_accuracy_fn, label='val_accuracy - fine-tuning')
plt.plot(epochs, accuracy_fe, label='training_accuracy - feature extraction')
plt.plot(epochs, val_accuracy_fe, label='val_accuracy - feature extraction')
plt.title('Accuracy of Xception')
plt.xlabel('Epochs')
plt.legend();

# %% [markdown]
# **Evaluating using the testing data**

# %%
loss, accuracy = model.evaluate(test_ds, batch_size=32)
print(f"Model loss on test set: {(loss):.2f}")
print(f"Model accuracy on test set: {(accuracy*100):.2f}%")
# Out:
# 16/16 [==============================] - 33s 2s/step - loss: 0.1872 - accuracy: 0.9480
# Model loss on test set: 0.19
# Model accuracy on test set: 94.80%

# %% [markdown]
# **Confusion Matrix**

# %%
# Model prediction for test data
pred = model.predict(test_ds)

# Match the prediction class to the highest prediction probability
y_pred = [pred[i].argmax() for i in range(len(pred))]
y_pred_class = [class_names[y_pred[i]] for i in range(len(y_pred))]

# Extract the truth ground label and match to class_names 
y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_true_class = [class_names[y_true[i]] for i in range(len(y_true))]

# %%
# Plotting confusion matrix
cm = confusion_matrix(y_true=y_true, y_pred=y_pred)
plt.figure(figsize=(10,8))
ax = sns.heatmap(cm/np.sum(cm),fmt='.2%', annot=True, cmap='YlOrRd')
ax.set_title('Confusion Matrix\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.show()

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_true_class, y_pred_class, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      adipose      0.983     1.000     0.991        57
#      complex      0.894     0.868     0.881        68
#       debris      0.903     0.956     0.929        68
#        empty      1.000     1.000     1.000        59
#       lympho      0.968     0.968     0.968        63
#       mucosa      1.000     0.967     0.983        60
#       stroma      0.850     0.879     0.864        58
#        tumor      1.000     0.955     0.977        67
#
#     accuracy                          0.948       500
#    macro avg      0.950     0.949     0.949       500
# weighted avg      0.949     0.948     0.948       500
