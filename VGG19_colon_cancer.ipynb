# %% [markdown]
# <a href="https://colab.research.google.com/github/tushar-marine/colon_cancer/blob/main/VGG19_colon_cancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Adding Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##**Moving to working directory**

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/thesis')
# !ls
# Out:
# '~'				  VGG16_colon_cancer.ipynb
#  InceptionV3_colon_cancer.ipynb   VGG19_colon_cancer.ipynb
#  ResNet50V2_colon_cancer.ipynb	  Xception_colon_cancer.ipynb

# %% [markdown]
# #**Importing required libraries**

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# #**Data Preprocessing**

# %% [markdown]
# ##**Loading the data from form tensorflow_datasets**

# %%
tfds.disable_progress_bar()

# Reserve 10% for validation and 10% for test
(train_ds, validation_ds, test_ds), info = tfds.load("colorectal_histology",
                                                     split=["train[:80%]", "train[80%:90%]", "train[90%:]"],
                                                     as_supervised=True,
                                                     with_info=True)

print("Number of training examples: %d" % tf.data.experimental.cardinality(train_ds))
print("Number of validation examples: %d" % tf.data.experimental.cardinality(validation_ds))
print("Number of test examples: %d" % tf.data.experimental.cardinality(test_ds))

num_classes = info.features['label'].num_classes
print("Number of classes: %d" % num_classes)

original_image_size = info.features['image'].shape
print(f"Original image size: {original_image_size}")
# Out:
# Number of training examples: 4000
# Number of validation examples: 500
# Number of test examples: 500
# Number of classes: 8
# Original image size: (150, 150, 3)

# %%
# Get class names
class_names = info.features["label"].names
print(f"class names are: {class_names}")
# Out:
# class names are: ['tumor', 'stroma', 'complex', 'lympho', 'debris', 'mucosa', 'adipose', 'empty']

# %%
plt.figure(figsize=(12, 12))
for i, (image, label) in enumerate(train_ds.take(20)):
    ax = plt.subplot(4, 5, i + 1)
    plt.imshow(image)
    plt.title(class_names[int(label)])
    plt.axis("off")

# %% [markdown]
# ##**Standardizing the data**

# %%
# Resizing the images
img_size = (150, 150)

train_ds = train_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))
validation_ds = validation_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))
test_ds = test_ds.map(lambda x, y: (tf.image.resize(x, img_size), y))

# %%
# Batch, cache, and prefetch the data
batch_size = 32
train_ds = train_ds.cache().batch(batch_size).prefetch(buffer_size=5)
validation_ds = validation_ds.cache().batch(batch_size).prefetch(buffer_size=5)
test_ds = test_ds.cache().batch(batch_size).prefetch(buffer_size=5)

# %% [markdown]
# ##**Random data augmentation**

# %%
# Creating a data augmentation stage with horizontal flipping, rotations and zooms
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
], name ="data_augmentation")

# %%
# Visualizing the 1st image of the 1st batch after 20 random augmentation
for images, labels in train_ds.take(1):
    plt.figure(figsize=(12, 12))
    image = images[0]
    for i in range(20):
        ax = plt.subplot(4, 5, i + 1)
        aug_img = data_augmentation(tf.expand_dims(image, 0), training=True)
        plt.imshow(tf.squeeze(aug_img).numpy().astype("int32"))
        plt.title(class_names[int(labels[0])])
        plt.axis("off")

# %% [markdown]
# #**Building models**

# %% [markdown]
# ##**VGG19**

# %%
from tensorflow.keras.applications import VGG19

# %% [markdown]
# **Feature Extraction**

# %%
# Setup input shape and base model
input_shape = img_size + (3, )
base_model = VGG19(weights="imagenet", input_shape=input_shape, include_top=False)

# Freeze the base_model
base_model.trainable = False

# Create a new model on top
inputs = keras.Input(shape=input_shape, name="input_layer")

# Apply random data augmentation
x = data_augmentation(inputs)  

# Scaling input to a range of (-1., +1.) from (0, 255) 
x = keras.layers.Rescaling(scale=1/127.5, offset=-1)(x)

# Running the base_model in inference mode so that batchnorm statistics don't get updated even for fine-tuning.
x = base_model(x, training=False)

# Convert outputs of the base model to vectors
x = keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

# Create the output activation layer
outputs = keras.layers.Dense(num_classes, activation="softmax", name="output_layer")(x)

# Combine the inputs with the outputs into a model
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 150, 150, 3)]     0
#
#  data_augmentation (Sequenti  (None, 150, 150, 3)      0
#  al)
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_average_pooling_laye  (None, 512)              0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 8)                 4104
#
# =================================================================
# Total params: 20,028,488
# Trainable params: 4,104
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Compiling VGG19 model
model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# Fit the model
history_feature_extraction = model.fit(train_ds, epochs=20, validation_data=validation_ds)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 1251s 10s/step - loss: 1.5618 - accuracy: 0.5210 - val_loss: 1.0694 - val_accuracy: 0.7420
# Epoch 2/20
# 125/125 [==============================] - 1259s 10s/step - loss: 0.9752 - accuracy: 0.7465 - val_loss: 0.8021 - val_accuracy: 0.7840
# Epoch 3/20
# 125/125 [==============================] - 1248s 10s/step - loss: 0.8042 - accuracy: 0.7638 - val_loss: 0.6916 - val_accuracy: 0.8040
# Epoch 4/20
# 125/125 [==============================] - 1245s 10s/step - loss: 0.7137 - accuracy: 0.7912 - val_loss: 0.6298 - val_accuracy: 0.8100
# Epoch 5/20
# 125/125 [==============================] - 1245s 10s/step - loss: 0.6646 - accuracy: 0.7962 - val_loss: 0.5861 - val_accuracy: 0.8180
# Epoch 6/20
# 125/125 [==============================] - 1243s 10s/step - loss: 0.6255 - accuracy: 0.8005 - val_loss: 0.5596 - val_accuracy: 0.8240
# Epoch 7/20
# 125/125 [==============================] - 1242s 10s/step - loss: 0.5963 - accuracy: 0.8052 - val_loss: 0.5357 - val_accuracy: 0.8320
# Epoch 8/20
# 125/125 [==============================] - 1241s 10s/step - loss: 0.5743 - accuracy: 0.8170 - val_loss: 0.5156 - val_accuracy: 0.8300
# Epoch 9/20
# 125/125 [==============================] - 1243s 10s/step - loss: 0.5568 - accuracy: 0.8213 - val_loss: 0.5004 - val_accuracy: 0.8400
# Epoch 10/20
# 125/125 [==============================] - 1242s 10s/step - loss: 0.5427 - accuracy: 0.8135 - val_loss: 0.4865 - val_accuracy: 0.8420
# Epoch 11/20
# 125/125 [==============================] - 1240s 10s/step - loss: 0.5258 - accuracy: 0.8245 - val_loss: 0.4795 - val_accuracy: 0.8380
# Epoch 12/20
# 125/125 [==============================] - 1247s 10s/step - loss: 0.5160 - accuracy: 0.8280 - val_loss: 0.4683 - val_accuracy: 0.8460
# Epoch 13/20
# 125/125 [==============================] - 1244s 10s/step - loss: 0.5099 - accuracy: 0.8245 - val_loss: 0.4608 - val_accuracy: 0.8480
# Epoch 14/20
# 125/125 [==============================] - 1242s 10s/step - loss: 0.4906 - accuracy: 0.8372 - val_loss: 0.4511 - val_accuracy: 0.8600
# Epoch 15/20
# 125/125 [==============================] - 1242s 10s/step - loss: 0.4842 - accuracy: 0.8315 - val_loss: 0.4443 - val_accuracy: 0.8560
# Epoch 16/20
# 125/125 [==============================] - 1241s 10s/step - loss: 0.4764 - accuracy: 0.8428 - val_loss: 0.4372 - val_accuracy: 0.8600
# Epoch 17/20
# 125/125 [==============================] - 1247s 10s/step - loss: 0.4639 - accuracy: 0.8432 - val_loss: 0.4363 - val_accuracy: 0.8540
# Epoch 18/20
# 125/125 [==============================] - 1239s 10s/step - loss: 0.4550 - accuracy: 0.8510 - val_loss: 0.4261 - val_accuracy: 0.8600
# Epoch 19/20
# 125/125 [==============================] - 1241s 10s/step - loss: 0.4592 - accuracy: 0.8410 - val_loss: 0.4231 - val_accuracy: 0.8620
# Epoch 20/20
# 125/125 [==============================] - 1241s 10s/step - loss: 0.4519 - accuracy: 0.8468 - val_loss: 0.4200 - val_accuracy: 0.8660

# %%
# Unfreeze the entire base model
base_model.trainable = True

# Freeze all layers except the last 10 layers
for layer in base_model.layers[:-10]: 
  layer.trainable = False

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_layer (InputLayer)    [(None, 150, 150, 3)]     0
#
#  data_augmentation (Sequenti  (None, 150, 150, 3)      0
#  al)
#
#  rescaling (Rescaling)       (None, 150, 150, 3)       0
#
#  vgg19 (Functional)          (None, 4, 4, 512)         20024384
#
#  global_average_pooling_laye  (None, 512)              0
#  r (GlobalAveragePooling2D)
#
#  output_layer (Dense)        (None, 8)                 4104
#
# =================================================================
# Total params: 20,028,488
# Trainable params: 17,702,920
# Non-trainable params: 2,325,568
# _________________________________________________________________

# %%
# Compiling the model
model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), metrics=["accuracy"])

# Fitting the model
history_fine_tuning = model.fit(train_ds, epochs=20, validation_data=validation_ds)
# Out:
# Epoch 1/20
# 125/125 [==============================] - 2512s 20s/step - loss: 0.3936 - accuracy: 0.8555 - val_loss: 0.3164 - val_accuracy: 0.8900
# Epoch 2/20
# 125/125 [==============================] - 2521s 20s/step - loss: 0.3011 - accuracy: 0.8967 - val_loss: 0.2864 - val_accuracy: 0.9040
# Epoch 3/20
# 125/125 [==============================] - 2540s 20s/step - loss: 0.2632 - accuracy: 0.9078 - val_loss: 0.2677 - val_accuracy: 0.9140
# Epoch 4/20
# 125/125 [==============================] - 2592s 21s/step - loss: 0.2341 - accuracy: 0.9200 - val_loss: 0.2651 - val_accuracy: 0.9080
# Epoch 5/20
# 125/125 [==============================] - 2572s 21s/step - loss: 0.2177 - accuracy: 0.9237 - val_loss: 0.2889 - val_accuracy: 0.9000
# Epoch 6/20
# 125/125 [==============================] - 2601s 21s/step - loss: 0.2031 - accuracy: 0.9260 - val_loss: 0.2698 - val_accuracy: 0.9080
# Epoch 7/20
# 125/125 [==============================] - 2602s 21s/step - loss: 0.1735 - accuracy: 0.9373 - val_loss: 0.2257 - val_accuracy: 0.9180
# Epoch 8/20
# 125/125 [==============================] - 2609s 21s/step - loss: 0.1774 - accuracy: 0.9367 - val_loss: 0.2265 - val_accuracy: 0.9280
# Epoch 9/20
# 125/125 [==============================] - 2576s 21s/step - loss: 0.1659 - accuracy: 0.9408 - val_loss: 0.2466 - val_accuracy: 0.9180
# Epoch 10/20
# 125/125 [==============================] - 2581s 21s/step - loss: 0.1630 - accuracy: 0.9430 - val_loss: 0.2632 - val_accuracy: 0.9140
# Epoch 11/20
# 125/125 [==============================] - 2577s 21s/step - loss: 0.1393 - accuracy: 0.9510 - val_loss: 0.2278 - val_accuracy: 0.9300
# Epoch 12/20
# 125/125 [==============================] - 2576s 21s/step - loss: 0.1378 - accuracy: 0.9528 - val_loss: 0.2153 - val_accuracy: 0.9380
# Epoch 13/20
# 125/125 [==============================] - 2571s 21s/step - loss: 0.1380 - accuracy: 0.9507 - val_loss: 0.2112 - val_accuracy: 0.9320
# Epoch 14/20
# 125/125 [==============================] - 2562s 21s/step - loss: 0.1254 - accuracy: 0.9555 - val_loss: 0.2275 - val_accuracy: 0.9280
# Epoch 15/20
# 125/125 [==============================] - 2560s 20s/step - loss: 0.1244 - accuracy: 0.9578 - val_loss: 0.2137 - val_accuracy: 0.9340
# Epoch 16/20
# 125/125 [==============================] - 2552s 20s/step - loss: 0.1103 - accuracy: 0.9615 - val_loss: 0.1917 - val_accuracy: 0.9420
# Epoch 17/20
# 125/125 [==============================] - 2549s 20s/step - loss: 0.1133 - accuracy: 0.9625 - val_loss: 0.1981 - val_accuracy: 0.9420
# Epoch 18/20
# 125/125 [==============================] - 2545s 20s/step - loss: 0.1018 - accuracy: 0.9622 - val_loss: 0.2193 - val_accuracy: 0.9200
# Epoch 19/20
# 125/125 [==============================] - 2551s 20s/step - loss: 0.0965 - accuracy: 0.9670 - val_loss: 0.2196 - val_accuracy: 0.9480
# Epoch 20/20
# 125/125 [==============================] - 2556s 20s/step - loss: 0.0910 - accuracy: 0.9668 - val_loss: 0.2026 - val_accuracy: 0.9380

# %% [markdown]
# ###**Evaluation**

# %% [markdown]
# **Loss Curve**

# %%
# Comparing accuracy and loss curves for training and validation sets for feature extraction and fine-tuning 
loss_fn = history_fine_tuning.history['loss']
val_loss_fn = history_fine_tuning.history['val_loss']
accuracy_fn = history_fine_tuning.history['accuracy']
val_accuracy_fn = history_fine_tuning.history['val_accuracy']

loss_fe = history_feature_extraction.history['loss']
val_loss_fe = history_feature_extraction.history['val_loss']
accuracy_fe = history_feature_extraction.history['accuracy']
val_accuracy_fe = history_feature_extraction.history['val_accuracy']

epochs = range(len(history_fine_tuning.history['loss']))

# Plotting loss curve
plt.figure()
plt.plot(epochs, loss_fn, label='training loss - fine-tuning')
plt.plot(epochs, val_loss_fn, label='val loss - fine-tuning')
plt.plot(epochs, loss_fe, label='training loss - feature extraction')
plt.plot(epochs, val_loss_fe, label='val loss - feature extraction')
plt.title('Loss Curve of VGG19')
plt.xlabel('Epochs')
plt.legend();

# Plotting accuracy
plt.figure()
plt.plot(epochs, accuracy_fn, label='training_accuracy - fine-tuning')
plt.plot(epochs, val_accuracy_fn, label='val_accuracy - fine-tuning')
plt.plot(epochs, accuracy_fe, label='training_accuracy - feature extraction')
plt.plot(epochs, val_accuracy_fe, label='val_accuracy - feature extraction')
plt.title('Accuracy of VGG19')
plt.xlabel('Epochs')
plt.legend();

# %% [markdown]
# **Evaluating using the testing data**

# %%
loss, accuracy = model.evaluate(test_ds, batch_size=32)
print(f"Model loss on test set: {(loss):.2f}")
print(f"Model accuracy on test set: {(accuracy*100):.2f}%")
# Out:
# 16/16 [==============================] - 139s 9s/step - loss: 0.1980 - accuracy: 0.9260
# Model loss on test set: 0.20
# Model accuracy on test set: 92.60%

# %% [markdown]
# **Confusion Matrix**

# %%
# Model prediction for test data
pred = model.predict(test_ds)

# Match the prediction class to the highest prediction probability
y_pred = [pred[i].argmax() for i in range(len(pred))]
y_pred_class = [class_names[y_pred[i]] for i in range(len(y_pred))]

# Extract the truth ground label and match to class_names 
y_true = np.concatenate([y for x, y in test_ds], axis=0)
y_true_class = [class_names[y_true[i]] for i in range(len(y_true))]

# %%
# Plotting confusion matrix
cm = confusion_matrix(y_true=y_true, y_pred=y_pred)
plt.figure(figsize=(10,8))
ax = sns.heatmap(cm/np.sum(cm),fmt='.2%', annot=True, cmap='YlOrRd')
ax.set_title('Confusion Matrix\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');
ax.xaxis.set_ticklabels(class_names)
ax.yaxis.set_ticklabels(class_names)
plt.show()

# %% [markdown]
# **Classification Report**

# %%
print(classification_report(y_true_class, y_pred_class, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#      adipose      0.983     1.000     0.991        57
#      complex      0.810     0.750     0.779        68
#       debris      0.917     0.971     0.943        68
#        empty      0.983     1.000     0.992        59
#       lympho      0.923     0.952     0.938        63
#       mucosa      0.967     0.983     0.975        60
#       stroma      0.918     0.776     0.841        58
#        tumor      0.917     0.985     0.950        67
#
#     accuracy                          0.926       500
#    macro avg      0.927     0.927     0.926       500
# weighted avg      0.925     0.926     0.924       500
